# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **A Patel**
#
# Doctor

# %% [markdown]
# *I am interested in data science because i want to improve patient care and explore and interest at the same time.*

# %% [markdown]
# ### Addition function

# %%
def add_num(a,b):
    return a + b ;
add_num(1,2)
# Out:
# 3

# %% [markdown]
# | Item.         | Price         | Material |
# | ------------- |:-------------:| --------:|
# | chair         | 3000          |   gold   |
# | necklace      | 2000          |  silver  |
# | watch         | 400           |  bronze  |
#
#
# ~~remove.~~
#
# *emphasise*
#
#
# 1. First item
# 2. Item 2
# 1. Item 3
# 4. Item 4
